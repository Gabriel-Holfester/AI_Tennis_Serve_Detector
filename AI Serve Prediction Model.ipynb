# %%
import numpy as np
print(np.__version__)
# Out:
# 1.24.3

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv

# Load yolo pre trained model 
model = YOLO("yolov8n.pt")

results = model.train(data="Tennis Ball Detection CI project.v2i.yolov8/data.yaml", epochs=100, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.4.35 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.34 🚀 Python-3.11.5 torch-2.0.1+cu117 CUDA:0 (Tesla V100-PCIE-16GB, 16144MiB)
# ...
